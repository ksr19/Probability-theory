# %% [markdown]
# # Урок 7. Многомерный статистический анализ. Линейная регрессия

# %%
import numpy as np
import random as rand

# %% [markdown]
# 1. Даны значения величины заработной платы заемщиков банка (zp) и значения их поведенческого кредитного скоринга (ks): zp = [35, 45, 190, 200, 40, 70, 54, 150, 120, 110], ks = [401, 574, 874, 919, 459, 739, 653, 902, 746, 832]. Используя математические операции, посчитать коэффициенты линейной регрессии, приняв за X заработную плату (то есть, zp - признак), а за y - значения скорингового балла (то есть, ks - целевая переменная). Произвести расчет как с использованием intercept, так и без.

# %%
zp = np.array([35, 45, 190, 200, 40, 70, 54, 150, 120, 110])
ks = np.array([401, 574, 874, 919, 459, 739, 653, 902, 746, 832])

# %%
X = zp.reshape(len(zp), 1)
y = ks.reshape(len(ks), 1)
X
# Out:
# array([[ 35],
#        [ 45],
#        [190],
#        [200],
#        [ 40],
#        [ 70],
#        [ 54],
#        [150],
#        [120],
#        [110]])

# %% [markdown]
# Сначала рассмотрим случай, когда у нас нет свободного члена, то есть без intercept. Тогда уравнение линейной регрессии имеет следующий вид:
# ### $$y=\beta_1\cdot x$$
# Определим коэффициент $\beta_1$:

# %%
B = np.dot(np.linalg.inv(np.dot(X.T, X)),X.T@y)
B
# Out:
# array([[5.88982042]])

# %% [markdown]
# То есть уравнение линейной регрессии может быть переписано так:
# ### $$y= 5.8898\cdot x$$

# %% [markdown]
# Теперь рассмотрим случай, когда в уравнении регрессии присутствует свободный член/intercept. Уравнение имеет вид:
# ### $$y=\beta_0 + \beta_1 \cdot x$$

# %%
X = np.hstack((np.ones((len(ks),1)),X))
B = np.dot(np.linalg.inv(np.dot(X.T, X)),X.T@y)
B
# Out:
# array([[444.17735732],
#        [  2.62053888]])

# %% [markdown]
# То есть уравнение регрессии будет выглядеть следующим образом:
# ### $$y= 444.1774 + 2.6205\cdot x$$

# %% [markdown]
# 2. Посчитать коэффициент линейной регрессии при заработной плате (zp), используя градиентный спуск (без intercept).

# %%
zp = np.array([35, 45, 190, 200, 40, 70, 54, 150, 120, 110])
ks = np.array([401, 574, 874, 919, 459, 739, 653, 902, 746, 832])

# %%
def mse_(B1, y=ks, X=zp, n=len(ks)):
    return np.sum((B1*X-y)**2)/n

# %%
rand.seed(0)
alpha = 1e-5
n=len(ks)
B1 = rand.random()
B1
# Out:
# 0.8444218515250481

# %%
for i in range(20):
    B1 -= alpha * (2/n) * np.sum((B1*X-y)*X)
    print(f'Iteration: {i},  B1 = {B1}, mse = {mse_(B1)}')
# Out:
# Iteration: 0,  B1 = 2.2487717214936183, mse = 239156.4907389598
# Iteration: 1,  B1 = 3.2661501760926086, mse = 151350.08969242842
# Iteration: 2,  B1 = 4.003187962769938, mse = 105553.04087884635
# Iteration: 3,  B1 = 4.537133513252756, mse = 81724.7557670199
# Iteration: 4,  B1 = 4.923949299408933, mse = 69369.14529291284
# Iteration: 5,  B1 = 5.2041772220582025, mse = 62993.32893330303
# Iteration: 6,  B1 = 5.4071877801656205, mse = 59725.90061314446
# Iteration: 7,  B1 = 5.554258372965424, mse = 58068.129579039305
# Iteration: 8,  B1 = 5.660803369778056, mse = 57239.42468265382
# Iteration: 9,  B1 = 5.737989679628973, mse = 56834.44450340768
# Iteration: 10,  B1 = 5.79390714742785, mse = 56643.59426194893
# Iteration: 11,  B1 = 5.834416445139811, mse = 56559.147073210144
# Iteration: 12,  B1 = 5.863763324848646, mse = 56526.21234433165
# Iteration: 13,  B1 = 5.8850236131599525, mse = 56517.17540642889
# Iteration: 14,  B1 = 5.900425586506501, mse = 56518.40786377451
# Iteration: 15,  B1 = 5.911583515293462, mse = 56523.3834586148
# Iteration: 16,  B1 = 5.9196668544873186, mse = 56529.1307438566
# Iteration: 17,  B1 = 5.925522813399629, mse = 56534.418908867534
# Iteration: 18,  B1 = 5.929765151121734, mse = 56538.84010427777
# Iteration: 19,  B1 = 5.932838504199839, mse = 56542.35277940333

# %% [markdown]
# Начиная с 15ой итерации значение ошибки перестает уменьшаться и даже начинает несколько возрастать, значит уравнение регрессии в данном случае можно записать в виде:
# ### $$y= 5.8850\cdot x$$

# %% [markdown]
# 3. Произвести вычисления как в пункте 2, но с вычислением intercept. Учесть, что изменение коэффициентов должно производиться на каждом шаге одновременно (то есть изменение одного коэффициента не должно влиять на изменение другого во время одной итерации).

# %%
zp = np.array([35, 45, 190, 200, 40, 70, 54, 150, 120, 110])
ks = np.array([401, 574, 874, 919, 459, 739, 653, 902, 746, 832])

# %%
def mse_(B0, B1, y=ks, X=zp, n=len(ks)):
    return np.sum((B0+B1*X-y)**2)/n

# %%
rand.seed(21)
alpha = 1e-5
n=len(ks)
B0 = rand.random()
B1 = rand.random()
print(f'Initial values: B0 = {B0}, B1 = {B1}')
# Out:
# Initial values: B0 = 0.16494947983319797, B1 = 0.6897669242175674

# %%
for i in range(50001):
    B0_old, B1_old = (B0, B1)
    B0 = B0_old - alpha * (2/n) * np.sum((B0_old+B1_old*X-y))
    B1 = B1_old - alpha * (2/n) * np.sum((B0_old+B1_old*X-y)*X)
    if i % 1000 == 0:
        print(f'Iteration: {i},  B0 = {B0}, B1 = {B1}, mse = {mse_(B0, B1)}')
# Out:
# Iteration: 0,  B0 = 0.19192623919320706, B1 = 2.1363944521808698, mse = 250415.13811707395
# Iteration: 1000,  B0 = 16.24371286197959, B1 = 5.820616465538819, mse = 52958.29191232661
# Iteration: 2000,  B0 = 31.87508520314413, B1 = 5.7044281258679765, mse = 49625.08749476494
# Iteration: 3000,  B0 = 47.123910419470356, B1 = 5.591083267518589, mse = 46492.93844909324
# Iteration: 4000,  B0 = 61.99955060019299, B1 = 5.480512301872316, mse = 43551.14773946794
# Iteration: 5000,  B0 = 76.51113871580807, B1 = 5.37264734335551, mse = 40789.55940110538
# Iteration: 6000,  B0 = 90.66758422530343, B1 = 5.267422167760564, mse = 38198.531796138675
# Iteration: 7000,  B0 = 104.47757854616403, B1 = 5.164772171587226, mse = 35768.912176791455
# Iteration: 8000,  B0 = 117.94960039050915, B1 = 5.064634332378978, mse = 33492.01249231376
# Iteration: 9000,  B0 = 131.09192097063814, B1 = 4.966947170030099, mse = 31359.586379205684
# Iteration: 10000,  B0 = 143.91260907718106, B1 = 4.871650709039652, mse = 29363.80727718671
# Iteration: 11000,  B0 = 156.41953603297142, B1 = 4.778686441689243, mse = 27497.247616159275
# Iteration: 12000,  B0 = 168.62038052568147, B1 = 4.6879972921219375, mse = 25752.859022069708
# Iteration: 13000,  B0 = 180.52263332219147, B1 = 4.599527581300238, mse = 24123.953492095556
# Iteration: 14000,  B0 = 192.13360186757907, B1 = 4.513222992821702, mse = 22604.18549199485
# Iteration: 15000,  B0 = 203.46041477156265, B1 = 4.429030539571109, mse = 21187.534930736812
# Iteration: 16000,  B0 = 214.5100261851447, B1 = 4.346898531188764, mse = 19868.29096971434
# Iteration: 17000,  B0 = 225.2892200701451, B1 = 4.266776542334969, mse = 18641.03662590754
# Iteration: 18000,  B0 = 235.8046143642458, B1 = 4.188615381731152, mse = 17500.634130339837
# Iteration: 19000,  B0 = 246.06266504411062, B1 = 4.112367061958606, mse = 16442.211005042853
# Iteration: 20000,  B0 = 256.06967008905673, B1 = 4.0379847699964255, mse = 15461.146823533947
# Iteration: 21000,  B0 = 265.8317733477349, B1 = 3.965422838480397, mse = 14553.060621504288
# Iteration: 22000,  B0 = 275.35496831016894, B1 = 3.8946367176653314, mse = 13713.798926036257
# Iteration: 23000,  B0 = 284.64510178749185, B1 = 3.825582948073516, mse = 12939.424373202484
# Iteration: 24000,  B0 = 293.70787750162185, B1 = 3.7582191338125632, mse = 12226.204885365727
# Iteration: 25000,  B0 = 302.54885958709104, B1 = 3.692503916546246, mse = 11570.603380889055
# Iteration: 26000,  B0 = 311.1734760071712, B1 = 3.6283969501023554, mse = 10969.267990291906
# Iteration: 27000,  B0 = 319.5870218863975, B1 = 3.565858875701977, mse = 10419.02275414774
# Iteration: 28000,  B0 = 327.79466276153585, B1 = 3.504851297794981, mse = 9916.858779219225
# Iteration: 29000,  B0 = 335.8014377529913, B1 = 3.445336760486868, mse = 9459.925830468035
# Iteration: 30000,  B0 = 343.6122626585966, B1 = 3.387278724542576, mse = 9045.524337663393
# Iteration: 31000,  B0 = 351.23193297169144, B1 = 3.3306415449530236, mse = 8671.097796345912
# Iteration: 32000,  B0 = 358.66512682533835, B1 = 3.2753904490506907, mse = 8334.22554388788
# Iteration: 33000,  B0 = 365.9164078644855, B1 = 3.22149151516077, mse = 8032.615892326548
# Iteration: 34000,  B0 = 372.9902280478375, B1 = 3.1689116517747933, mse = 7764.099600537394
# Iteration: 35000,  B0 = 379.8909303811558, B1 = 3.1176185772339546, mse = 7526.623669162026
# Iteration: 36000,  B0 = 386.6227515836716, B1 = 3.0675807999095985, mse = 7318.245442511019
# Iteration: 37000,  B0 = 393.18982468923576, B1 = 3.0187675988688194, mse = 7137.127002430146
# Iteration: 38000,  B0 = 399.59618158381704, B1 = 2.9711490050131757, mse = 6981.529839847244
# Iteration: 39000,  B0 = 405.8457554808965, B1 = 2.9246957826790316, mse = 6849.809790412495
# Iteration: 40000,  B0 = 411.9423833362834, B1 = 2.879379411688176, mse = 6740.412221305289
# Iteration: 41000,  B0 = 417.88980820383415, B1 = 2.8351720698377085, mse = 6651.867456909834
# Iteration: 42000,  B0 = 423.6916815335157, B1 = 2.7920466158184865, mse = 6582.7864316601335
# Iteration: 43000,  B0 = 429.35156541322965, B1 = 2.7499765725515912, mse = 6531.856558924042
# Iteration: 44000,  B0 = 434.8729347557781, B1 = 2.7089361109325703, mse = 6497.8378053379465
# Iteration: 45000,  B0 = 440.25917943229854, B1 = 2.668900033973559, mse = 6479.558960519195
# Iteration: 46000,  B0 = 445.5136063534926, B1 = 2.6298437613334666, mse = 6475.914092573576
# Iteration: 47000,  B0 = 450.6394414999211, B1 = 2.591743314226747, mse = 6485.859180281896
# Iteration: 48000,  B0 = 455.63983190260814, B1 = 2.5545753007015226, mse = 6508.4089132937825
# Iteration: 49000,  B0 = 460.51784757517794, B1 = 2.5183169012779687, mse = 6542.633652079092
# Iteration: 50000,  B0 = 465.276483398702, B1 = 2.482945854938204, mse = 6587.656539789496

# %% [markdown]
# Как видим минимальное значение ошибки достигается для итерации с номером 46000. Значит уравнение регрессии можно записать следующим образом:
# ### $$y = 445.5136 + 2.6298 \cdot x$$
